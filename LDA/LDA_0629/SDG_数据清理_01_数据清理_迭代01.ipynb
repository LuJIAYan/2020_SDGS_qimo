# %% [markdown]
# # 数据清理、断词、等
#
# * 断词
# ![](https://aiacademy.tw/wp-content/uploads/2020/01/ma-natural-language-processing-10.jpg)

# %%
fn = { "input" : "data_sets/raw_data_gathered.xlsx",
       "output" : "data_sets/raw_data_processed.xlsx"
      }

# %% [markdown]
# # 集成代码

# %%
# 你来试试?

# %% [markdown]
# # 分解流程丶代码及说明
# ## 读入数据

# %% [markdown]
# # 注释1：导入模块读取抓取的数据集

# %%
import pandas as pd
df = pd.read_excel("get_contents.xlsx", sheet_name= "17goal", index_col=0).fillna("")
df.head()
# Out:
#                             title  \
# 0               目标1：在全世界消除一切形式的贫困
# 1  目标2：消除饥饿，实现粮食安全，改善营养状况和促进可持续农业
# 2       目标3：确保健康的生活方式，促进各年龄段人群的福祉
# 3    目标4：确保包容和公平的优质教育，让全民终身享有学习机会
# 4         目标5：实现性别平等，增强所有妇女和女童的权能
#
#                                                  url  \
# 0  https://www.un.org/sustainabledevelopment/zh/p...
# 1  https://www.un.org/sustainabledevelopment/zh/h...
# 2  https://www.un.org/sustainabledevelopment/zh/h...
# 3  https://www.un.org/sustainabledevelopment/zh/e...
# 4  https://www.un.org/sustainabledevelopment/zh/g...
#
#                                              content
# 0  在全球范围内，生活在极端贫困中的人口比例从1990年的36%下降到2015年的10%。但是，...
# 1  饥饿人口数量（按营养不足发生率计算）已持续下降数十年，从2015年又开始缓慢增加。如今，超过...
# 2  确保健康的生活方式，促进各年龄段所有人的福祉对可持续发展至关重要。当前，世界正面临一场前所未...
# 3  教育能够提升社会经济地位，更是摆脱贫困的关键。过去十年间，各级教育机会大幅增加，入学率显著提...
# 4  性别平等不仅是一项基本人权，也是世界和平、繁荣和可持续发展的必要基础。过去几十年取得的：上学...

# %% [markdown]
# ##  清理标题title
# 由於标题title 符号编码都不一，所以进行处理
# * title_raw title

# %%
# 备分
df = df.rename (columns = {"title":"title_title"})
df_original = df.copy()
df_original
# Out:
#                                           title_title  \
# 0                                   目标1：在全世界消除一切形式的贫困
# 1                      目标2：消除饥饿，实现粮食安全，改善营养状况和促进可持续农业
# 2                           目标3：确保健康的生活方式，促进各年龄段人群的福祉
# 3                        目标4：确保包容和公平的优质教育，让全民终身享有学习机会
# 4                             目标5：实现性别平等，增强所有妇女和女童的权能
# 5                          目标6：为所有人提供水和环境卫生并对其进行可持续管理
# 6                         目标7：确保人人获得负担得起的、可靠和可持续的现代能源
# 7             目标8：促进持久、包容和可持续经济增长，促进充分的生产性就业和人人获得体面工作
# 8             目标9：建造具备抵御灾害能力的基础设施，促进具有包容性的可持续工业化，推动创新
# 9                                目标10：减少国家内部和国家之间的不平等
# 10                   目标11：建设包容、安全、有抵御灾害能力和可持续的城市和人类住区
# 11                               目标12：\t采用可持续的消费和生产模式
# 12                              目标13：采取紧急行动应对气候变化及其影响
# 13                     目标14：\t保护和可持续利用海洋和海洋资源以促进可持续发展
# 14  目标15：保护、恢复和促进可持续利用陆地生态系统，可持续管理森林，防治荒漠化，制止和扭转土地...
# 15  目标16：创建和平、包容的社会以促进可持续发展，让所有人都能诉诸司法，在各级建立有效、负责和...
# 16                          目标17：加强执行手段，重振可持续发展全球伙伴关系
#
#                                                   url  \
# 0   https://www.un.org/sustainabledevelopment/zh/p...
# 1   https://www.un.org/sustainabledevelopment/zh/h...
# 2   https://www.un.org/sustainabledevelopment/zh/h...
# 3   https://www.un.org/sustainabledevelopment/zh/e...
# 4   https://www.un.org/sustainabledevelopment/zh/g...
# 5   https://www.un.org/sustainabledevelopment/zh/w...
# 6   https://www.un.org/sustainabledevelopment/zh/e...
# 7   https://www.un.org/sustainabledevelopment/zh/e...
# 8   https://www.un.org/sustainabledevelopment/zh/i...
# 9   https://www.un.org/sustainabledevelopment/zh/i...
# 10  https://www.un.org/sustainabledevelopment/zh/c...
# 11  https://www.un.org/sustainabledevelopment/zh/s...
# 12  https://www.un.org/sustainabledevelopment/zh/c...
# 13  https://www.un.org/sustainabledevelopment/zh/o...
# 14  https://www.un.org/sustainabledevelopment/zh/b...
# 15  https://www.un.org/sustainabledevelopment/zh/p...
# 16  https://www.un.org/sustainabledevelopment/zh/g...
#
#                                               content
# 0   在全球范围内，生活在极端贫困中的人口比例从1990年的36%下降到2015年的10%。但是，...
# 1   饥饿人口数量（按营养不足发生率计算）已持续下降数十年，从2015年又开始缓慢增加。如今，超过...
# 2   确保健康的生活方式，促进各年龄段所有人的福祉对可持续发展至关重要。当前，世界正面临一场前所未...
# 3   教育能够提升社会经济地位，更是摆脱贫困的关键。过去十年间，各级教育机会大幅增加，入学率显著提...
# 4   性别平等不仅是一项基本人权，也是世界和平、繁荣和可持续发展的必要基础。过去几十年取得的：上学...
# 5   尽管获得清洁饮用水和卫生设施的机会已大大增加，但仍有数十亿人缺乏这些基本服务，他们大多生活在...
# 6   世界各国正。种种积极迹象表明，能源正变得更可持续，并得到广泛普及。较贫穷国家的电力供应已经开...
# 7   持续和包容的经济增长可以推动进步，为所有人创造体面的就业机会，并改善生活水平。2019冠状病...
# 8   包容性、可持续的工业化，加上，能够释放经济活力，提高经济竞争力，从而创造就业岗位和收入，在引...
# 9   减少不平等现象并确保不让任何一个人掉队，对实现可持续发展目标至关重要。国家内部和国家之间的不...
# 10  全球城市化程度越来越高。自2007年以来，，预计到2030年，这个比例将上升至60%。城市和...
# 11  全球的消费和生产推动全球经济发展，但依赖于对自然环境和资源的利用，目前的利用模式会持续对地球...
# 12  2019年是，也是有记录以来最热的十年(2010-2019)的最后一年。2019年，大气中的...
# 13  海洋驱动着多个全球系统，让地球变得适宜人类居住。我们的雨水、饮用水、天气、气候、海岸线、多种...
# 14  自然对我们的生存至关重要。自然为我们提供氧气，调节天气状况，让农作物得以授粉，为我们提供粮食...
# 15  当今世界冲突不断，安全形势严峻，机构能力不足，人们诉诸司法的渠道有限。这些问题仍然是可持续发...
# 16  只有加强全球伙伴关系和合作，才能实现可持续发展目标。一项成功的发展议程需要在全球、区域、国家...

# %% [markdown]
# # 注释2：联合国17个目标标题没有特殊符号，故注释掉本段代码。

# %%
'''
import collections

def extract_title (text):
    text = text.replace ("大赛作品","").strip()
    numb = text[0]
    text = text[1:]

    if "｜" in text:
        sep = "｜"
    elif "|" in text:
        sep = "|"
    else:
        sep = None
    
    if sep is not None:
        title = text.split(sep)[1]

    if "（" in title:
        sep = "（"
    elif "(" in text:
        sep = "("
    else:
        sep = None        
        
    if sep is not None:
        title = title.split(sep)[0]
    
    return (numb, title)
     
def extract_title_list (ordered_dict):
    test_list_out = []
    for i,text in ordered_dict.items():
        numb, title = extract_title (text)
        out = {"i":i, "numb":numb,"title":title}
        test_list_out.append(out)
    return (test_list_out)

extract_title_list (df.title_raw.to_dict()) 
'''
# Out:
# '\nimport collections\n\ndef extract_title (text):\n    text = text.replace ("大赛作品","").strip()\n    numb = text[0]\n    text = text[1:]\n\n    if "｜" in text:\n        sep = "｜"\n    elif "|" in text:\n        sep = "|"\n    else:\n        sep = None\n    \n    if sep is not None:\n        title = text.split(sep)[1]\n\n    if "（" in title:\n        sep = "（"\n    elif "(" in text:\n        sep = "("\n    else:\n        sep = None        \n        \n    if sep is not None:\n        title = title.split(sep)[0]\n    \n    return (numb, title)\n     \ndef extract_title_list (ordered_dict):\n    test_list_out = []\n    for i,text in ordered_dict.items():\n        numb, title = extract_title (text)\n        out = {"i":i, "numb":numb,"title":title}\n        test_list_out.append(out)\n    return (test_list_out)\n\nextract_title_list (df.title_raw.to_dict()) \n'

# %% [markdown]
# # 注释4：联合国17个目标标题没有特殊符号，无更新数据，故注释掉本段代码。

# %%
'''
df_更新数据 = pd.DataFrame( extract_title_list (df_original.title_raw.to_dict())  ).set_index("i")
df = df_更新数据.join(df_original).sort_values(by="numb").reset_index()
df

'''
# Out:
# '\ndf_更新数据 = pd.DataFrame( extract_title_list (df_original.title_raw.to_dict())  ).set_index("i")\ndf = df_更新数据.join(df_original).sort_values(by="numb").reset_index()\ndf\n\n'

# %% [markdown]
# ##   使用jieba做断词
# * https://github.com/fxsjy/jieba
# * pip install jieba
#
# ```python
# import jieba
#
# seg_list = list(jieba.cut("我来到北京清华大学", cut_all=True))
# print(seg_list)  # 全模式
#
# seg_list = list(jieba.cut("我来到北京清华大学", cut_all=False))
# print(seg_list)  # 精确模式
# ```
#
# ```
# ['我', '来到', '北京', '清华', '清华大学', '华大', '大学']
# ['我', '来到', '北京', '清华大学']
# ```

# %%
import jieba

seg_list = list(jieba.cut("我来到北京清华大学", cut_all=True))
print(seg_list)  # 全模式

seg_list = list(jieba.cut("我来到北京清华大学", cut_all=False))
print(seg_list)  # 精确模式
# Out:
# ['我', '来到', '北京', '清华', '清华大学', '华大', '大学']
# ['我', '来到', '北京', '清华大学']

# %%
import jieba

"""JieBa类"""
class JieBa:   
    #定义基本属性
    user_dict_path = False
    stopwords_path = False
    stopwords = []
    #定义私有属性,私有属性在类外部无法直接进行访问
    __weight = 0
    #定义构造方法
    def __init__(self, udp=False, stp=False):
        self.user_dict_path = udp
        self.stopwords_path = stp
        
        # 用户自定字典启动
        if udp!=False:
            jieba.load_userdict(udp)
            jieba.set_dictionary(udp)  #加载自定义词典  
            jieba.initialize()# 旦有必要才开始加载词典构建前缀字典。
            
        # 停止词字典启动
        if stp!=False:
            zh_stopwords = pd.read_csv(stp, encoding="utf8", header=None)  # 读入中文停止词
            self.stopwords = list(zh_stopwords[0].values)

            # 读入中文及英文标点
            import sys
            from unicodedata import category as cat
            tbl_p = [chr(i) for i in range(sys.maxunicode) if cat(chr(i)).startswith('P')]
            # print(tbl_p)
            
            self.stopwords.extend(tbl_p)
            
    def preprocess (self, _text_):  
        _text_ = re.sub( r'\s+', " ", _text_) ## preprocessing, removing whitespaces(multiple) to 1 
        return (_text_)
    
    def postprocess (self, _list_, stopwords):
        return ([x.strip() for x in _list_ if x not in stopwords+[' ']])  # 把stopwords 及 " "过滤掉
    
    def cut(self, _text_):
        #print (_text_)
        return (self.postprocess(list(jieba.cut(self.preprocess(_text_))), self.stopwords))

    def cut_text(self, _text_, sep=" "):
        return (sep.join(self.cut(_text_)))
    

"""JieBa类实例"""
JB = JieBa()                                                                  # 均无
#JB = JieBa(udp="data_sets/JieBa_user_dict.txt")                               # 仅使用用户自定字典
#JB = JieBa(stp="data_sets/JieBa_stopwords.txt")                               # 仅使用停止词字典
#JB = JieBa(udp="data_sets/JieBa_user_dict.txt", stp="data_sets/JieBa_stopwords.txt")

# %%
print (JB.stopwords)
# Out:
# []

# %% [markdown]
# # 注释5：这里需要观察抓取的数据集，第四列为内容，对内容进行断词。

# %%
#对列表中第4列的内容进行分词处理
import re
JB.cut_text(df.loc[4,"content"])
# Out:
# '性别 平等 不仅 是 一项 基本 人权 ， 也 是 世界 和平 、 繁荣 和 可 持续 发展 的 必要 基础 。 过去 几十年 取得 的 ： 上学 的 女童 人数 增多 ， 被迫 早婚 的 女童 人数 减少 ， 更 多 的 妇女 任职 于 议会 和 担任 领导 ， 并且 法律 正在 朝着 促进 性别 平等 的 方向 改革 。 尽管如此 ， 仍然 存在 许多 ： 歧视性 的 法律 和 社会规范 仍然 普遍存在 ； 各级 政治 领导层 中 的 妇女 人数 仍然 不足 ； 在 一年 内 ， 15 至 49 岁 的 妇女 和 女童 中有 五分之一 曾 遭受 来自 亲密 伴侣 的 人身 暴力 或 性暴力 。 ， 可能 扭转 在 性别 平等 和 妇女 权利 方面 取得 的 有限 进展 。 此次 冠状病毒 的 暴发 。 在 应对 这一 病毒 的 过程 中 ， 妇女 发挥 着 极为重要 的 作用 ， 她们 有的是 前线 医护人员 ， 有的是 家庭 照护 者 。 由于 学校 停课 和 老年人 的 需求 增加 ， 妇女 的 无偿 照料 工作 大幅 增加 。 2019 冠状病毒 病 的 经济 影响 对 妇女 造成 了 更 大 的 打击 ， 因为 她们 在 无 保障 的 劳动力 市场 就业 的 比例 更高 。 近 60% 的 妇女 在 非正规 经济 部门 工作 ， 因此 ， 她们 更 易 陷入 贫困 。 此次 大 流行病 还 导致 急剧 增加 。 由于 封锁 措施 的 实施 ， 许多 妇女 被迫 与 施虐 者 待 在 家中 ， 难以获得 已 遭到 削减 和 限制 的 服务 。 最新 的 数据 显示 ， 自大 流行病 暴发 以来 ， 暴力 侵害 妇女 和 女童 的 行为 （ 特别 是 家庭暴力 ） 加剧 。 把 妇女 和 女童 放在 经济 发展 的 中心 位置 ， 将 从根本上 为 各国 带来 更好 、 更 可 持续 的 发展 成果 ， 为 更 迅速 的 恢复 提供 支持 ， 并 使 世界 重回 实现 可 持续 发展 目标 的 轨道 。 每一项 2019 冠状病毒 病 应对 计划 、 综合 恢复 措施 和 资源 预算 都 需要 。 这 意味着 ： ( 1 ) 将 妇女 和 妇女组织 纳入 2019 冠状病毒 病 的 应对 计划 和 决策 中 ； ( 2 ) 将 不 平等 的 无偿 照料 工作 转化 为 适用 于 所有人 的 新型 包容性 护理 经济 ； ( 3 ) 在 制定 社会 经济 计划 时 ， 着重 关注 妇女 和 女童 的 生活 和 未来 。 联合国 促进 性别 平等 和 增强 妇女 权能 署 （ 妇女 署 ） 已 制定 了 有 针对性 的 快速 措施 ， 旨在 减轻 2019 冠状病毒 病 危机 对 妇女 和 女童 的 影响 ， 并 确保 她们 能够 受益 于 长期 的 恢复 工作 ， 主要 关注 以下 五个 优先 事项 ：'

# %%
JB.cut_text(df.loc[4,"content"])
# Out:
# '性别 平等 不仅 是 一项 基本 人权 ， 也 是 世界 和平 、 繁荣 和 可 持续 发展 的 必要 基础 。 过去 几十年 取得 的 ： 上学 的 女童 人数 增多 ， 被迫 早婚 的 女童 人数 减少 ， 更 多 的 妇女 任职 于 议会 和 担任 领导 ， 并且 法律 正在 朝着 促进 性别 平等 的 方向 改革 。 尽管如此 ， 仍然 存在 许多 ： 歧视性 的 法律 和 社会规范 仍然 普遍存在 ； 各级 政治 领导层 中 的 妇女 人数 仍然 不足 ； 在 一年 内 ， 15 至 49 岁 的 妇女 和 女童 中有 五分之一 曾 遭受 来自 亲密 伴侣 的 人身 暴力 或 性暴力 。 ， 可能 扭转 在 性别 平等 和 妇女 权利 方面 取得 的 有限 进展 。 此次 冠状病毒 的 暴发 。 在 应对 这一 病毒 的 过程 中 ， 妇女 发挥 着 极为重要 的 作用 ， 她们 有的是 前线 医护人员 ， 有的是 家庭 照护 者 。 由于 学校 停课 和 老年人 的 需求 增加 ， 妇女 的 无偿 照料 工作 大幅 增加 。 2019 冠状病毒 病 的 经济 影响 对 妇女 造成 了 更 大 的 打击 ， 因为 她们 在 无 保障 的 劳动力 市场 就业 的 比例 更高 。 近 60% 的 妇女 在 非正规 经济 部门 工作 ， 因此 ， 她们 更 易 陷入 贫困 。 此次 大 流行病 还 导致 急剧 增加 。 由于 封锁 措施 的 实施 ， 许多 妇女 被迫 与 施虐 者 待 在 家中 ， 难以获得 已 遭到 削减 和 限制 的 服务 。 最新 的 数据 显示 ， 自大 流行病 暴发 以来 ， 暴力 侵害 妇女 和 女童 的 行为 （ 特别 是 家庭暴力 ） 加剧 。 把 妇女 和 女童 放在 经济 发展 的 中心 位置 ， 将 从根本上 为 各国 带来 更好 、 更 可 持续 的 发展 成果 ， 为 更 迅速 的 恢复 提供 支持 ， 并 使 世界 重回 实现 可 持续 发展 目标 的 轨道 。 每一项 2019 冠状病毒 病 应对 计划 、 综合 恢复 措施 和 资源 预算 都 需要 。 这 意味着 ： ( 1 ) 将 妇女 和 妇女组织 纳入 2019 冠状病毒 病 的 应对 计划 和 决策 中 ； ( 2 ) 将 不 平等 的 无偿 照料 工作 转化 为 适用 于 所有人 的 新型 包容性 护理 经济 ； ( 3 ) 在 制定 社会 经济 计划 时 ， 着重 关注 妇女 和 女童 的 生活 和 未来 。 联合国 促进 性别 平等 和 增强 妇女 权能 署 （ 妇女 署 ） 已 制定 了 有 针对性 的 快速 措施 ， 旨在 减轻 2019 冠状病毒 病 危机 对 妇女 和 女童 的 影响 ， 并 确保 她们 能够 受益 于 长期 的 恢复 工作 ， 主要 关注 以下 五个 优先 事项 ：'

# %%
df
# Out:
#                                           title_title  \
# 0                                   目标1：在全世界消除一切形式的贫困
# 1                      目标2：消除饥饿，实现粮食安全，改善营养状况和促进可持续农业
# 2                           目标3：确保健康的生活方式，促进各年龄段人群的福祉
# 3                        目标4：确保包容和公平的优质教育，让全民终身享有学习机会
# 4                             目标5：实现性别平等，增强所有妇女和女童的权能
# 5                          目标6：为所有人提供水和环境卫生并对其进行可持续管理
# 6                         目标7：确保人人获得负担得起的、可靠和可持续的现代能源
# 7             目标8：促进持久、包容和可持续经济增长，促进充分的生产性就业和人人获得体面工作
# 8             目标9：建造具备抵御灾害能力的基础设施，促进具有包容性的可持续工业化，推动创新
# 9                                目标10：减少国家内部和国家之间的不平等
# 10                   目标11：建设包容、安全、有抵御灾害能力和可持续的城市和人类住区
# 11                               目标12：\t采用可持续的消费和生产模式
# 12                              目标13：采取紧急行动应对气候变化及其影响
# 13                     目标14：\t保护和可持续利用海洋和海洋资源以促进可持续发展
# 14  目标15：保护、恢复和促进可持续利用陆地生态系统，可持续管理森林，防治荒漠化，制止和扭转土地...
# 15  目标16：创建和平、包容的社会以促进可持续发展，让所有人都能诉诸司法，在各级建立有效、负责和...
# 16                          目标17：加强执行手段，重振可持续发展全球伙伴关系
#
#                                                   url  \
# 0   https://www.un.org/sustainabledevelopment/zh/p...
# 1   https://www.un.org/sustainabledevelopment/zh/h...
# 2   https://www.un.org/sustainabledevelopment/zh/h...
# 3   https://www.un.org/sustainabledevelopment/zh/e...
# 4   https://www.un.org/sustainabledevelopment/zh/g...
# 5   https://www.un.org/sustainabledevelopment/zh/w...
# 6   https://www.un.org/sustainabledevelopment/zh/e...
# 7   https://www.un.org/sustainabledevelopment/zh/e...
# 8   https://www.un.org/sustainabledevelopment/zh/i...
# 9   https://www.un.org/sustainabledevelopment/zh/i...
# 10  https://www.un.org/sustainabledevelopment/zh/c...
# 11  https://www.un.org/sustainabledevelopment/zh/s...
# 12  https://www.un.org/sustainabledevelopment/zh/c...
# 13  https://www.un.org/sustainabledevelopment/zh/o...
# 14  https://www.un.org/sustainabledevelopment/zh/b...
# 15  https://www.un.org/sustainabledevelopment/zh/p...
# 16  https://www.un.org/sustainabledevelopment/zh/g...
#
#                                               content
# 0   在全球范围内，生活在极端贫困中的人口比例从1990年的36%下降到2015年的10%。但是，...
# 1   饥饿人口数量（按营养不足发生率计算）已持续下降数十年，从2015年又开始缓慢增加。如今，超过...
# 2   确保健康的生活方式，促进各年龄段所有人的福祉对可持续发展至关重要。当前，世界正面临一场前所未...
# 3   教育能够提升社会经济地位，更是摆脱贫困的关键。过去十年间，各级教育机会大幅增加，入学率显著提...
# 4   性别平等不仅是一项基本人权，也是世界和平、繁荣和可持续发展的必要基础。过去几十年取得的：上学...
# 5   尽管获得清洁饮用水和卫生设施的机会已大大增加，但仍有数十亿人缺乏这些基本服务，他们大多生活在...
# 6   世界各国正。种种积极迹象表明，能源正变得更可持续，并得到广泛普及。较贫穷国家的电力供应已经开...
# 7   持续和包容的经济增长可以推动进步，为所有人创造体面的就业机会，并改善生活水平。2019冠状病...
# 8   包容性、可持续的工业化，加上，能够释放经济活力，提高经济竞争力，从而创造就业岗位和收入，在引...
# 9   减少不平等现象并确保不让任何一个人掉队，对实现可持续发展目标至关重要。国家内部和国家之间的不...
# 10  全球城市化程度越来越高。自2007年以来，，预计到2030年，这个比例将上升至60%。城市和...
# 11  全球的消费和生产推动全球经济发展，但依赖于对自然环境和资源的利用，目前的利用模式会持续对地球...
# 12  2019年是，也是有记录以来最热的十年(2010-2019)的最后一年。2019年，大气中的...
# 13  海洋驱动着多个全球系统，让地球变得适宜人类居住。我们的雨水、饮用水、天气、气候、海岸线、多种...
# 14  自然对我们的生存至关重要。自然为我们提供氧气，调节天气状况，让农作物得以授粉，为我们提供粮食...
# 15  当今世界冲突不断，安全形势严峻，机构能力不足，人们诉诸司法的渠道有限。这些问题仍然是可持续发...
# 16  只有加强全球伙伴关系和合作，才能实现可持续发展目标。一项成功的发展议程需要在全球、区域、国家...

# %% [markdown]
# ##  新增栏位doc
# 由於标题丶描述丶及文本都具意义，所以我们新增栏位"文本"doc，把所有的文本整合起来

# %%
#源数据没有desc数据，故注释掉

'''
分隔符号 = "-----"
df['doc'] = [分隔符号.join([df.title[i], df.desc[i] , df.content[i] ] )   for i in df.index] 
df
'''

分隔符号 = "-----"
df['doc'] = [分隔符号.join([df.title_raw[i],  df.content[i] ] )   for i in df.index] 
df
# Out:
#                                             title_raw  \
# 0                                   目标1：在全世界消除一切形式的贫困
# 1                      目标2：消除饥饿，实现粮食安全，改善营养状况和促进可持续农业
# 2                           目标3：确保健康的生活方式，促进各年龄段人群的福祉
# 3                        目标4：确保包容和公平的优质教育，让全民终身享有学习机会
# 4                             目标5：实现性别平等，增强所有妇女和女童的权能
# 5                          目标6：为所有人提供水和环境卫生并对其进行可持续管理
# 6                         目标7：确保人人获得负担得起的、可靠和可持续的现代能源
# 7             目标8：促进持久、包容和可持续经济增长，促进充分的生产性就业和人人获得体面工作
# 8             目标9：建造具备抵御灾害能力的基础设施，促进具有包容性的可持续工业化，推动创新
# 9                                目标10：减少国家内部和国家之间的不平等
# 10                   目标11：建设包容、安全、有抵御灾害能力和可持续的城市和人类住区
# 11                               目标12：\t采用可持续的消费和生产模式
# 12                              目标13：采取紧急行动应对气候变化及其影响
# 13                     目标14：\t保护和可持续利用海洋和海洋资源以促进可持续发展
# 14  目标15：保护、恢复和促进可持续利用陆地生态系统，可持续管理森林，防治荒漠化，制止和扭转土地...
# 15  目标16：创建和平、包容的社会以促进可持续发展，让所有人都能诉诸司法，在各级建立有效、负责和...
# 16                          目标17：加强执行手段，重振可持续发展全球伙伴关系
#
#                                                   url  \
# 0   https://www.un.org/sustainabledevelopment/zh/p...
# 1   https://www.un.org/sustainabledevelopment/zh/h...
# 2   https://www.un.org/sustainabledevelopment/zh/h...
# 3   https://www.un.org/sustainabledevelopment/zh/e...
# 4   https://www.un.org/sustainabledevelopment/zh/g...
# 5   https://www.un.org/sustainabledevelopment/zh/w...
# 6   https://www.un.org/sustainabledevelopment/zh/e...
# 7   https://www.un.org/sustainabledevelopment/zh/e...
# 8   https://www.un.org/sustainabledevelopment/zh/i...
# 9   https://www.un.org/sustainabledevelopment/zh/i...
# 10  https://www.un.org/sustainabledevelopment/zh/c...
# 11  https://www.un.org/sustainabledevelopment/zh/s...
# 12  https://www.un.org/sustainabledevelopment/zh/c...
# 13  https://www.un.org/sustainabledevelopment/zh/o...
# 14  https://www.un.org/sustainabledevelopment/zh/b...
# 15  https://www.un.org/sustainabledevelopment/zh/p...
# 16  https://www.un.org/sustainabledevelopment/zh/g...
#
#                                               content  \
# 0   在全球范围内，生活在极端贫困中的人口比例从1990年的36%下降到2015年的10%。但是，...
# 1   饥饿人口数量（按营养不足发生率计算）已持续下降数十年，从2015年又开始缓慢增加。如今，超过...
# 2   确保健康的生活方式，促进各年龄段所有人的福祉对可持续发展至关重要。当前，世界正面临一场前所未...
# 3   教育能够提升社会经济地位，更是摆脱贫困的关键。过去十年间，各级教育机会大幅增加，入学率显著提...
# 4   性别平等不仅是一项基本人权，也是世界和平、繁荣和可持续发展的必要基础。过去几十年取得的：上学...
# 5   尽管获得清洁饮用水和卫生设施的机会已大大增加，但仍有数十亿人缺乏这些基本服务，他们大多生活在...
# 6   世界各国正。种种积极迹象表明，能源正变得更可持续，并得到广泛普及。较贫穷国家的电力供应已经开...
# 7   持续和包容的经济增长可以推动进步，为所有人创造体面的就业机会，并改善生活水平。2019冠状病...
# 8   包容性、可持续的工业化，加上，能够释放经济活力，提高经济竞争力，从而创造就业岗位和收入，在引...
# 9   减少不平等现象并确保不让任何一个人掉队，对实现可持续发展目标至关重要。国家内部和国家之间的不...
# 10  全球城市化程度越来越高。自2007年以来，，预计到2030年，这个比例将上升至60%。城市和...
# 11  全球的消费和生产推动全球经济发展，但依赖于对自然环境和资源的利用，目前的利用模式会持续对地球...
# 12  2019年是，也是有记录以来最热的十年(2010-2019)的最后一年。2019年，大气中的...
# 13  海洋驱动着多个全球系统，让地球变得适宜人类居住。我们的雨水、饮用水、天气、气候、海岸线、多种...
# 14  自然对我们的生存至关重要。自然为我们提供氧气，调节天气状况，让农作物得以授粉，为我们提供粮食...
# 15  当今世界冲突不断，安全形势严峻，机构能力不足，人们诉诸司法的渠道有限。这些问题仍然是可持续发...
# 16  只有加强全球伙伴关系和合作，才能实现可持续发展目标。一项成功的发展议程需要在全球、区域、国家...
#
#                                                   doc
# 0   目标1：在全世界消除一切形式的贫困-----在全球范围内，生活在极端贫困中的人口比例从199...
# 1   目标2：消除饥饿，实现粮食安全，改善营养状况和促进可持续农业-----饥饿人口数量（按营养不...
# 2   目标3：确保健康的生活方式，促进各年龄段人群的福祉-----确保健康的生活方式，促进各年龄段...
# 3   目标4：确保包容和公平的优质教育，让全民终身享有学习机会-----教育能够提升社会经济地位，...
# 4   目标5：实现性别平等，增强所有妇女和女童的权能-----性别平等不仅是一项基本人权，也是世界...
# 5   目标6：为所有人提供水和环境卫生并对其进行可持续管理-----尽管获得清洁饮用水和卫生设施的...
# 6   目标7：确保人人获得负担得起的、可靠和可持续的现代能源-----世界各国正。种种积极迹象表明...
# 7   目标8：促进持久、包容和可持续经济增长，促进充分的生产性就业和人人获得体面工作-----持续...
# 8   目标9：建造具备抵御灾害能力的基础设施，促进具有包容性的可持续工业化，推动创新-----包容...
# 9   目标10：减少国家内部和国家之间的不平等-----减少不平等现象并确保不让任何一个人掉队，对...
# 10  目标11：建设包容、安全、有抵御灾害能力和可持续的城市和人类住区-----全球城市化程度越来...
# 11  目标12：\t采用可持续的消费和生产模式-----全球的消费和生产推动全球经济发展，但依赖于...
# 12  目标13：采取紧急行动应对气候变化及其影响-----2019年是，也是有记录以来最热的十年(...
# 13  目标14：\t保护和可持续利用海洋和海洋资源以促进可持续发展-----海洋驱动着多个全球系统...
# 14  目标15：保护、恢复和促进可持续利用陆地生态系统，可持续管理森林，防治荒漠化，制止和扭转土地...
# 15  目标16：创建和平、包容的社会以促进可持续发展，让所有人都能诉诸司法，在各级建立有效、负责和...
# 16  目标17：加强执行手段，重振可持续发展全球伙伴关系-----只有加强全球伙伴关系和合作，才能...

# %% [markdown]
# ## 重要性字典生成
# 详见[FE_文本字词_RF_随机森林_重要性](FE_文本字词_RF_随机森林_重要性.ipynb)

# %%
from collections import OrderedDict, defaultdict
import feature_extraction as FE

corpus = df.doc.to_dict(into=OrderedDict) 

# 文本矢量化: 特徵值提取
# %time M = FE.doc_vectorizer (corpus, max_df=0.7, min_df=0.03, max_features=50000 ) # 特徵值门槛   

# 文本-字词矩阵：降维结果前
# %time dfm = FE.gen_df_doc_term_matrix_from_model(M, kind="corpus_index")           # dfm的大小長寬是?

# 降维 2d -> 1d
# %time df_importance = FE.gen_df_importance_using_RandomForest(dfm, max_depth=100)  # max_depth愈浅愈..?

df_importance
# Out:
# Wall time: 4.99 ms
# Wall time: 997 µs
# Wall time: 514 ms
# D:\anaconda37\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# feature                      feature  importance
# rank_importance
# 1                     2019冠状病毒病大流行表明    0.031664
# 2                         降低脆弱性和经济风险    0.030838
# 3                          制止和扭转土地退化    0.030224
# 4                                 供水    0.027603
# 5                                近60    0.024201
# ...                              ...         ...
# 819                             在一年内    0.000000
# 820                    在全世界消除一切形式的贫困    0.000000
# 821                           在全球范围内    0.000000
# 822              在全球范围内的增加是一个令人关切的问题    0.000000
# 823                            饲料和纤维    0.000000
#
# [823 rows x 2 columns]

# %% [markdown]
# # 注释6：！这里需要对文本进行修正，需要半自动人工监督分词

# %%
def columns_add(df):
    df['类别'] = ""
    df['修正'] = ""
    df['memo'] = ""
    return(df)
df_importance = columns_add(df_importance)

# %%
df_importance
# Out:
# feature                      feature  importance 类别 修正 memo
# rank_importance
# 1                     2019冠状病毒病大流行表明    0.031664
# 2                         降低脆弱性和经济风险    0.030838
# 3                          制止和扭转土地退化    0.030224
# 4                                 供水    0.027603
# 5                                近60    0.024201
# ...                              ...         ... .. ..  ...
# 819                             在一年内    0.000000
# 820                    在全世界消除一切形式的贫困    0.000000
# 821                           在全球范围内    0.000000
# 822              在全球范围内的增加是一个令人关切的问题    0.000000
# 823                            饲料和纤维    0.000000
#
# [823 rows x 5 columns]

# %% [markdown]
# ## 重要性字典生成导出

# %% [markdown]
# # 注释7：打包保存文件是个好习惯！

# %%
import xls_io as xls
xls.check_and_write_xls (fn["output"], {"feature": df_importance}, get_time=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-74568a122bea> in <module>
#       1 import xls_io as xls
# ----> 2 xls.check_and_write_xls (fn["output"], {"feature": df_importance}, get_time=False)
#
# NameError: name 'fn' is not defined
